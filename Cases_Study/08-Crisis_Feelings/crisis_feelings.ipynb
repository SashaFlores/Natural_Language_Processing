# %% [markdown]
# # The Feelings of the Crisis
#
# When you read a news article, normally the headline is the hook to continue reading. However, a negative title could lead you to skip reading an article if you don't want to be in a bad mood. But is this accurate?
#
# On this activity you are tasked to corroborate if a news title with a negative sentiment leads or not to a negative content. You will use VADER sentiment to accomplish this work using the news articles that you previously download on _The Voice of the Crisis_ activity.

# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

get_ipython().run_line_magic("matplotlib", "inline")
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\ooshy\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ## Instructions
#
# Just for convenience download the `vader_lexicon` in order to initialize the VADER sentiment analyzer

# %%
# Download/Update the VADER Lexicon
nltk.download("vader_lexicon")

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ooshy\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Load the News Articles from the CSV File as a DataFrame
#
# Pick the CSV file you created on _The Voice of the Crisis_ activity and load it as a DataFrame, remember to specify the `encoding='utf-8-sig'` parameter.

# %%
# Load news from CSV file

article = pd.read_csv(Path('crisis_news_en_fr.csv'), encoding='utf-8-sig')
article
# Out:
#           date                                        description language  \
# 0   2020-08-31  What you can learn from a CEO who started a co...       en
# 1   2020-08-25  Rachel Kyte, the dean of the Fletcher School a...       en
# 2   2020-08-28  It’s been a week bookended with bad financial ...       en
# 3   2020-08-12  <ul>\n<li>Billionaire investor Carl Icahn made...       en
# 4   2020-08-15  As the pandemic wreaks havoc on public transit...       en
# 5   2020-08-19  COVID-19 caught us all off guard. While many b...       en
# 6   2020-08-12  ONS confirms recession as GDP falls 20.4% as C...       en
# 7   2020-09-07  Ireland's gross domestic product fell by 6.1% ...       en
# 8   2020-08-11  Ms. Harris sometimes struggled to clearly defi...       en
# 9   2020-08-17  Even before the pandemic, America’s colleges a...       en
# 10  2020-09-03  France unveils a 100bn-euro plan to kick-start...       en
# 11  2020-08-12  Global banks were left shell-shocked this year...       en
# 12  2020-08-12  Global banks were left shell-shocked this year...       en
# 13  2020-08-18  <ul>\n<li>A new paper from Federal Reserve res...       en
# 14  2020-09-03  Spanish lenders Bankia and Caixabank are consi...       en
# 15  2020-09-04  Spain's Caixabank <CABK.MC> and Bankia <BKIA.M...       en
# 16  2020-08-21  Joseph R. Biden Jr. never wavered from his cen...       en
# 17  2020-09-07  Spain's Prime Minister Pedro Sanchez on Monday...       en
# 18  2020-08-21  Japan's factory activity extended its fall in ...       en
# 19  2020-08-25  A contentious new fee on U.S. mortgage refinan...       en
# 20  2020-08-18  ENQUÊTE - L’impact du Covid-19 sur le marché e...       fr
# 21  2020-09-05  Premier commissaire aux investissements d'aven...       fr
# 22  2020-08-25  La Slovénie, d'ordinaire beaucoup plus calme, ...       fr
# 23  2020-08-13  Mark Carney aiderait Justin Trudeau à préparer...       fr
# 24  2020-09-02  Canberra doit faire face à des tensions grandi...       fr
# 25  2020-09-02  CONTRE-POINT - L’ampleur du choc a rendu leurs...       fr
# 26  2020-08-07  Pour la première fois depuis la création de l’...       fr
# 27  2020-09-07  Une fois de plus, un dossier financier a traîn...       fr
# 28  2020-08-18  Les indicateurs économiques ne suffiront pas à...       fr
# 29  2020-08-14  Alors que les perspectives économiques n'ont j...       fr
# 2      Maybe It's Time to Retire the Phrase 'Big Oil'
# 3   Carl Icahn netted $1.3 billion from betting ag...
# 4   Public Transit Cuts Felt Deepest in Low-Income...
# 5   Center-out management: The new leadership styl...
# 6   UK economy plunges into deepest slump since re...
# 7   Ireland enters shallower recession than most t...
# 8   Kamala Harris on the Issues: Race, Policing, H...
# 9   Breakingviews - Guest view: U.S. universities ...
# 10  France in huge coronavirus recovery plan focus...
# 11  Explainer: How commodity trade finance works -...
# 12  Explainer: How commodity trade finance works -...
# 13  Monopolies drive income inequality, financial ...
# 14  UPDATE 1-Caixabank and Bankia consider merger ...
# 15  Spanish lenders Caixabank, Bankia could close ...
# 16  Gaffes? Sure. But Biden’s Message Discipline W...
# 17  Spain's PM Sanchez sees positive aspects in Ba...
# 18  Japan's recovery hopes hit by Aug factory acti...
# 19  U.S. housing regulator postpones new mortgage ...
# 20         Le champagne affronte une crise historique
# 21  «On ne peut pas espérer tirer parti de ce plan...
# 22                  En Slovénie, la stratégie du choc
# 23  L’ex-gouverneur de la Banque d’Angleterre au s...
# 24  L’Australie victime à son tour de la récession...
# 25  Guillaume Tabard: «Sous les 100 milliards du p...
# 26  Malades du Covid-19, les géants du CAC 40 mult...
# 27  Fortis : douze ans plus tard, le dossier symbo...
# 28  Présidentielle américaine : l'économie sera-t-...
# 29                    La récession est-elle si grave?
# 30  Les dividendes mondiaux face à la pire chute d...
# 31  L'Australie en récession après trois décennies...
# 32  Quatre idées sérieusement mises à mal par la p...
# 33  Crise économique post Covid-19: qui gagne, qui...
# 34        La crise économique du Coronavirus arrive !
# 35                Coronavirus : la crise d'une époque
# 36  L'Australie en récession après trois décennies...
# 37  Le coronavirus va-t-il être fatal aux vins fra...
# 38                 A la rentrée fais gaffe à la récré
# 39  Foot: Kompany prend sa retraite et devient ent...

# %% [markdown]
# The VADER sentiment module is only trained to score sentiment on English language, so create a new DataFrame only with news in English. You will learn how to score sentiment in multiple languages later.

# %%
# Fetch only English news
df_en = article[article['language']=='en']

df_en.head()
# Out:
#          date                                        description language  \
# 0  2020-08-31  What you can learn from a CEO who started a co...       en
# 1  2020-08-25  Rachel Kyte, the dean of the Fletcher School a...       en
# 2  2020-08-28  It’s been a week bookended with bad financial ...       en
# 3  2020-08-12  <ul>\n<li>Billionaire investor Carl Icahn made...       en
# 4  2020-08-15  As the pandemic wreaks havoc on public transit...       en
#
#                                                 text  \
# 0  August\r\n31, 2020\r\n7 min read\r\nOpinions e...
# 1  You cant isolate yourself from a pandemic and ...
# 2  Its been a week bookended with bad financial n...
# 3  Brendan McDermid/Reuters\r\nBillionaire invest...
# 4  New Orleans, like most American cities, has se...
#
#                                                title
# 0  12 Leadership Lessons with NerdWallet CEO Tim ...
# 1  The Pandemic’s Economic Crisis Calls for a Gre...
# 2     Maybe It's Time to Retire the Phrase 'Big Oil'
# 3  Carl Icahn netted $1.3 billion from betting ag...
# 4  Public Transit Cuts Felt Deepest in Low-Income...

# %% [markdown]
# ### Calculating VADER Sentiment Score for News Titles and Text
#
# As you know the `compound` score could be used to get a normalized score for a sentiment, in this section you have to create a function called `get_sentiment(score)` that will return a normalized value of sentiment for the `score` parameter based on the rules you learn. This function should return `1` for positive sentiment, `-1` for negative sentiment, and `0` for neutral sentiment.

# %%
# Sentiment calculation based on compound score
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0 # Neutral by default
    if score >= 0.05:  #Postive
        result = 1
    elif score <= -0.05: # Negative
        result = -1
    return result

# %% [markdown]
# Use the the VADER sentiment module from `NLTK` to score the sentiment of every news article title and text in english; you should append ten new columns to the English news DataFrame to store the results as follows.
#
# * Title's compound score
# * Title's positive score
# * Title's neutral score
# * Title's negative score
# * Title's normalized score (using the `get_sentiment()` function)
# * Text's compound score
# * Text's positive score
# * Text's neutral score
# * Text's negative score
# * Text's normalized score (using the `get_sentiment()` function)

# %%
# Sentiment Scores Dictionaries

title_sent = {
    'title_compound':[],
    'title_pos':[],
    'title_neu' : [],
    'title_neg':[], 
    'title_sent': [],
}

text_sent = {
    'text_compound':[],
    'text_pos':[],
    'text_neu' : [],
    'text_neg':[], 
    'text_sent': [],
}

# %%
''''''
To get sentiment for the text & title

the VADER sentiment score for each news article's title & text is calculated within a for-loop,
this loop iterates across the df_en DataFrame using the iterrows() method to create the final result's Dataframe structure.

''''''

# %%
for index, row in df_en.iterrows():
    try:
        # Sentiment Score
        title_sentiment = analyzer.polarity_scores(row['title'])
        title_sent['title_compound'].append(title_sentiment['compound'])
        title_sent['title_pos'].append(title_sentiment['pos'])
        title_sent['title_neu'].append(title_sentiment['neu'])
        title_sent['title_neg'].append(title_sentiment['neg'])
        title_sent['title_sent'].append(get_sentiment(title_sentiment['compound']))
        
        text_sentiment = analyzer.polarity_scores(row['text'])
        text_sent['text_compound'].append(title_sentiment['compound'])
        text_sent['text_pos'].append(text_sentiment['pos'])
        text_sent['text_neu'].append(text_sentiment['neu'])
        text_sent['text_neg'].append(text_sentiment['neg'])
        text_sent['text_sent'].append(get_sentiment(text_sentiment['compound']))
    except AttributeError:
        pass

# Attaching sentiment columns to the news Dataframe
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
news_en_df = df_en.join(title_sentiment_df).join(text_sentiment_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-0495f6647fc3> in <module>
#      19
#      20 # Attaching sentiment columns to the news Dataframe
# ---> 21 title_sentiment_df = pd.DataFrame(title_sent)
#      22 text_sentiment_df = pd.DataFrame(text_sent)
#      23 news_en_df = df_en.join(title_sentiment_df).join(text_sentiment_df)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ### Analyzing Sentiments Results
#
# How the sentiment of the title and the text differs on news articles?
#
# To answer this question, on this section you will create a bar chart contrasting the normalized sentiment for the title and the text of each news article. Use the build-in `plot()` method of the Pandas DataFrame to create a bar chart like the one bellow. Be aware that you chart might differ from this one due to is made from a different news DataFrame.

# %% [markdown]
# Finally get the descriptive statistics from the English news DataFrame and discuss the analysis results with your partners.
